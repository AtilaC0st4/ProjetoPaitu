# %% [markdown]
# # Realizando as instalações e os imports necessários
# ```bash
# "Requests"
# ```

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\renat\anaconda3\lib\site-packages (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\renat\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\renat\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\renat\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\renat\anaconda3\lib\site-packages (from requests) (2023.5.7)

# %%
import requests

link = "https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=10000&$orderby=Data%20desc&$format=json"
Requesições = requests.get(link)
informacoes = Requesições.json()

print(informacoes)
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata$metadata#informacoes_diarias', 'value': [{'Data': '2024-04-22', 'Quantidade': 3191004929, 'Valor': 31910049.29, 'Denominacao': '0.01', 'Especie': 'Moedas'}, {'Data': '2024-04-22', 'Quantidade': 7955432287, 'Valor': 397771614.35, 'Denominacao': '0.05', 'Especie': 'Moedas'}, {'Data': '2024-04-22', 'Quantidade': 8112558459, 'Valor': 811255845.9, 'Denominacao': '0.10', 'Especie': 'Moedas'}, {'Data': '2024-04-22', 'Quantidade': 3648448354, 'Valor': 912112088.5, 'Denominacao': '0.25', 'Especie': 'Moedas'}, {'Data': '2024-04-22', 'Quantidade': 3678944185, 'Valor': 1839472092.5, 'Denominacao': '0.50', 'Especie': 'Moedas'}, {'Data': '2024-04-22', 'Quantidade': 148646998, 'Valor': 148646998.0, 'Denominacao': '1.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-22', 'Quantidade': 4220781626, 'Valor': 4220781626.0, 'Denominacao': '1.00', 'Especie': 'Moedas'}, {'Data': '2024-04-22', 'Quantidade': 1587398484, 'Valor': 3174796968.0, 'Denominacao': '2.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-22', 'Quantidade': 683293805, 'Valor': 3416469025.0, 'Denominacao': '5.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-22', 'Quantidade': 652983684, 'Valor': 6529836840.0, 'Denominacao': '10.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-22', 'Quantidade': 688049822, 'Valor': 13760996440.0, 'Denominacao': '20.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-22', 'Quantidade': 1671156137, 'Valor': 83557806850.0, 'Denominacao': '50.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-22', 'Quantidade': 1842081521, 'Valor': 184208152100.0, 'Denominacao': '100.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-22', 'Quantidade': 137411991, 'Valor': 27482398200.0, 'Denominacao': '200.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-19', 'Quantidade': 3191004929, 'Valor': 31910049.29, 'Denominacao': '0.01', 'Especie': 'Moedas'}, {'Data': '2024-04-19', 'Quantidade': 7955370287, 'Valor': 397768514.35, 'Denominacao': '0.05', 'Especie': 'Moedas'}, {'Data': '2024-04-19', 'Quantidade': 8112201459, 'Valor': 811220145.9, 'Denominacao': '0.10', 'Especie': 'Moedas'}, {'Data': '2024-04-19', 'Quantidade': 3648264354, 'Valor': 912066088.5, 'Denominacao': '0.25', 'Especie': 'Moedas'}, {'Data': '2024-04-19', 'Quantidade': 3678656685, 'Valor': 1839328342.5, 'Denominacao': '0.50', 'Especie': 'Moedas'}, {'Data': '2024-04-19', 'Quantidade': 148646998, 'Valor': 148646998.0, 'Denominacao': '1.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-19', 'Quantidade': 4220517626, 'Valor': 4220517626.0, 'Denominacao': '1.00', 'Especie': 'Moedas'}, {'Data': '2024-04-19', 'Quantidade': 1587417432, 'Valor': 3174834864.0, 'Denominacao': '2.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-19', 'Quantidade': 683047896, 'Valor': 3415239480.0, 'Denominacao': '5.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-19', 'Quantidade': 651939514, 'Valor': 6519395140.0, 'Denominacao': '10.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-19', 'Quantidade': 687285153, 'Valor': 13745703060.0, 'Denominacao': '20.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-19', 'Quantidade': 1671281064, 'Valor': 83564053200.0, 'Denominacao': '50.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-19', 'Quantidade': 1840776935, 'Valor': 184077693500.0, 'Denominacao': '100.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-19', 'Quantidade': 137355013, 'Valor': 27471002600.0, 'Denominacao': '200.00', 'Especie': 'Cédulas'}, {'Data': '2024-04-18', 'Quantidade': 3191004929, 'Valor': 31910049.29, 'Denominacao': '0.01', 'Especie': 'Moedas'}, {'Data': '2024-04-18', 'Quantidade': 7954739287, 'Valor': 397736964.35, 'Denominacao': '0.05', 'Especie': 'Moedas'}, {'Data': '2024-04-18', 'Quantidade': 8110979459, 'Valor': 811097945.9, 'Denominacao': '0.10', 'Especie': 'Moedas'}, {'Data': '2024-04-18', 'Quantidade': 3647577354, 'Valor': 911894338.5, 'Denominacao': '0.25', 'Especie': 'Moedas'}, {'Data': '2024-04-18', 'Quantidade': 3677958585, 'Valor': 1838979292.5, 'Denominacao' ...

# %%
import pandas as pd

Tabela = pd.DataFrame(informacoes["value"])
display(Tabela)
# Out:
#             Data  Quantidade         Valor Denominacao  Especie
# 0     2024-04-22  3191004929  3.191005e+07        0.01   Moedas
# 1     2024-04-22  7955432287  3.977716e+08        0.05   Moedas
# 2     2024-04-22  8112558459  8.112558e+08        0.10   Moedas
# 3     2024-04-22  3648448354  9.121121e+08        0.25   Moedas
# 4     2024-04-22  3678944185  1.839472e+09        0.50   Moedas
# ...          ...         ...           ...         ...      ...
# 9995  2021-06-18    70567947  1.411359e+10      200.00  Cédulas
# 9996  2021-06-17  3191178998  3.191179e+07        0.01   Moedas
# 9997  2021-06-17  7200512819  3.600256e+08        0.05   Moedas
# 9998  2021-06-17  7421822180  7.421822e+08        0.10   Moedas
# 9999  2021-06-17  3252338889  8.130847e+08        0.25   Moedas
#
# [10000 rows x 5 columns]
