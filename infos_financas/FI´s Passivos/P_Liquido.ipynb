# %%
! pip install requests

# %%
import requests
import json

url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.22936/dados?formato=json"

response = requests.get(url)

if response.status_code == 200:
    dados_ativos = response.json() 
    
    print("Dados coletados:")
    print(dados_ativos)
else:
    print("Erro ao conseguir os dados!. Status Code:", response.status_code)
# Out:
# Dados coletados:
# [{'data': '01/01/1995', 'valor': '0.0'}, {'data': '01/02/1995', 'valor': '0.0'}, {'data': '01/03/1995', 'valor': '0.0'}, {'data': '01/04/1995', 'valor': '0.0'}, {'data': '01/05/1995', 'valor': '0.0'}, {'data': '01/06/1995', 'valor': '0.0'}, {'data': '01/07/1995', 'valor': '0.0'}, {'data': '01/08/1995', 'valor': '0.0'}, {'data': '01/09/1995', 'valor': '0.0'}, {'data': '01/10/1995', 'valor': '0.0'}, {'data': '01/11/1995', 'valor': '0.0'}, {'data': '01/12/1995', 'valor': '0.0'}, {'data': '01/01/1996', 'valor': '0.0'}, {'data': '01/02/1996', 'valor': '0.0'}, {'data': '01/03/1996', 'valor': '0.0'}, {'data': '01/04/1996', 'valor': '0.0'}, {'data': '01/05/1996', 'valor': '0.0'}, {'data': '01/06/1996', 'valor': '0.0'}, {'data': '01/07/1996', 'valor': '0.0'}, {'data': '01/08/1996', 'valor': '0.0'}, {'data': '01/09/1996', 'valor': '0.0'}, {'data': '01/10/1996', 'valor': '0.0'}, {'data': '01/11/1996', 'valor': '0.0'}, {'data': '01/12/1996', 'valor': '0.0'}, {'data': '01/01/1997', 'valor': '0.0'}, {'data': '01/02/1997', 'valor': '0.0'}, {'data': '01/03/1997', 'valor': '0.0'}, {'data': '01/04/1997', 'valor': '0.0'}, {'data': '01/05/1997', 'valor': '0.0'}, {'data': '01/06/1997', 'valor': '0.0'}, {'data': '01/07/1997', 'valor': '0.0'}, {'data': '01/08/1997', 'valor': '0.0'}, {'data': '01/09/1997', 'valor': '0.0'}, {'data': '01/10/1997', 'valor': '0.0'}, {'data': '01/11/1997', 'valor': '0.0'}, {'data': '01/12/1997', 'valor': '0.0'}, {'data': '01/01/1998', 'valor': '0.0'}, {'data': '01/02/1998', 'valor': '0.0'}, {'data': '01/03/1998', 'valor': '0.0'}, {'data': '01/04/1998', 'valor': '0.0'}, {'data': '01/05/1998', 'valor': '0.0'}, {'data': '01/06/1998', 'valor': '0.0'}, {'data': '01/07/1998', 'valor': '0.0'}, {'data': '01/08/1998', 'valor': '0.0'}, {'data': '01/09/1998', 'valor': '0.0'}, {'data': '01/10/1998', 'valor': '0.0'}, {'data': '01/11/1998', 'valor': '0.0'}, {'data': '01/12/1998', 'valor': '0.0'}, {'data': '01/01/1999', 'valor': '0.0'}, {'data': '01/02/1999', 'valor': '0.0'}, {'data': '01/03/1999', 'valor': '0.0'}, {'data': '01/04/1999', 'valor': '0.0'}, {'data': '01/05/1999', 'valor': '0.0'}, {'data': '01/06/1999', 'valor': '0.0'}, {'data': '01/07/1999', 'valor': '0.0'}, {'data': '01/08/1999', 'valor': '0.0'}, {'data': '01/09/1999', 'valor': '0.0'}, {'data': '01/10/1999', 'valor': '0.0'}, {'data': '01/11/1999', 'valor': '0.0'}, {'data': '01/12/1999', 'valor': '0.0'}, {'data': '01/01/2000', 'valor': '0.0'}, {'data': '01/02/2000', 'valor': '0.0'}, {'data': '01/03/2000', 'valor': '0.0'}, {'data': '01/04/2000', 'valor': '0.0'}, {'data': '01/05/2000', 'valor': '0.0'}, {'data': '01/06/2000', 'valor': '0.0'}, {'data': '01/07/2000', 'valor': '0.0'}, {'data': '01/08/2000', 'valor': '0.0'}, {'data': '01/09/2000', 'valor': '0.0'}, {'data': '01/10/2000', 'valor': '0.0'}, {'data': '01/11/2000', 'valor': '0.0'}, {'data': '01/12/2000', 'valor': '0.0'}, {'data': '01/01/2001', 'valor': '0.0'}, {'data': '01/02/2001', 'valor': '0.0'}, {'data': '01/03/2001', 'valor': '0.0'}, {'data': '01/04/2001', 'valor': '0.0'}, {'data': '01/05/2001', 'valor': '0.0'}, {'data': '01/06/2001', 'valor': '0.0'}, {'data': '01/07/2001', 'valor': '0.0'}, {'data': '01/08/2001', 'valor': '0.0'}, {'data': '01/09/2001', 'valor': '0.0'}, {'data': '01/10/2001', 'valor': '0.0'}, {'data': '01/11/2001', 'valor': '0.0'}, {'data': '01/12/2001', 'valor': '0.0'}, {'data': '01/01/2002', 'valor': '0.0'}, {'data': '01/02/2002', 'valor': '0.0'}, {'data': '01/03/2002', 'valor': '0.0'}, {'data': '01/04/2002', 'valor': '0.0'}, {'data': '01/05/2002', 'valor': '0.0'}, {'data': '01/06/2002', 'valor': '0.0'}, {'data': '01/07/2002', 'valor': '0.0'}, {'data': '01/08/2002', 'valor': '0.0'}, {'data': '01/09/2002', 'valor': '0.0'}, {'data': '01/10/2002', 'valor': '0.0'}, {'data': '01/11/2002', 'valor': '0.0'}, {'data': '01/12/2002', 'valor': '0.0'}, {'data': '01/01/2003', 'valor': '0.0'}, {'data': '01/02/2003', 'valor': '0.0'}, {'data': '01/03/2003', 'valor': '0.0'}, {'data': '01/04/2003', 'valor': '0.0'}, ...

# %%
import requests
import pandas as pd

url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.22936/dados?formato=json"

response = requests.get(url)

if response.status_code == 200:
    dados_ativos = response.json() 
    
    tabela = pd.DataFrame(dados_ativos)
    
    display(tabela)
else:
    print("Erro ao conseguir os dados!. Status Code:", response.status_code)
# Out:
#            data   valor
# 0    01/01/1995     0.0
# 1    01/02/1995     0.0
# 2    01/03/1995     0.0
# 3    01/04/1995     0.0
# 4    01/05/1995     0.0
# ..          ...     ...
# 345  01/10/2023  -659.7
# 346  01/11/2023  -156.1
# 347  01/12/2023  -506.7
# 348  01/01/2024   553.6
# 349  01/02/2024   166.8
#
# [350 rows x 2 columns]
