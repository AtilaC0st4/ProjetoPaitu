# %%
#! pip install request

# %%
import requests
import json

url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.22913/dados?formato=json"

response = requests.get(url)

if response.status_code == 200:
    dados_ativos = response.json() 
    
    print("Dados coletados:")
    print(dados_ativos)
else:
    print("Erro ao conseguir os dados!. Status Code:", response.status_code)
# Out:
# Dados coletados:
# [{'data': '01/01/1995', 'valor': '0.6'}, {'data': '01/02/1995', 'valor': '11.7'}, {'data': '01/03/1995', 'valor': '15.0'}, {'data': '01/04/1995', 'valor': '5.3'}, {'data': '01/05/1995', 'valor': '20.2'}, {'data': '01/06/1995', 'valor': '0.4'}, {'data': '01/07/1995', 'valor': '1.5'}, {'data': '01/08/1995', 'valor': '3.5'}, {'data': '01/09/1995', 'valor': '2.5'}, {'data': '01/10/1995', 'valor': '0.9'}, {'data': '01/11/1995', 'valor': '11.4'}, {'data': '01/12/1995', 'valor': '35.8'}, {'data': '01/01/1996', 'valor': '0.2'}, {'data': '01/02/1996', 'valor': '6.2'}, {'data': '01/03/1996', 'valor': '15.8'}, {'data': '01/04/1996', 'valor': '4.3'}, {'data': '01/05/1996', 'valor': '0.4'}, {'data': '01/06/1996', 'valor': '1.1'}, {'data': '01/07/1996', 'valor': '7.0'}, {'data': '01/08/1996', 'valor': '1.7'}, {'data': '01/09/1996', 'valor': '101.0'}, {'data': '01/10/1996', 'valor': '2.8'}, {'data': '01/11/1996', 'valor': '14.3'}, {'data': '01/12/1996', 'valor': '7.0'}, {'data': '01/01/1997', 'valor': '2.5'}, {'data': '01/02/1997', 'valor': '8.1'}, {'data': '01/03/1997', 'valor': '9.5'}, {'data': '01/04/1997', 'valor': '18.6'}, {'data': '01/05/1997', 'valor': '10.1'}, {'data': '01/06/1997', 'valor': '9.8'}, {'data': '01/07/1997', 'valor': '16.1'}, {'data': '01/08/1997', 'valor': '20.7'}, {'data': '01/09/1997', 'valor': '2.3'}, {'data': '01/10/1997', 'valor': '9.2'}, {'data': '01/11/1997', 'valor': '222.9'}, {'data': '01/12/1997', 'valor': '94.2'}, {'data': '01/01/1998', 'valor': '21.1'}, {'data': '01/02/1998', 'valor': '21.8'}, {'data': '01/03/1998', 'valor': '55.3'}, {'data': '01/04/1998', 'valor': '10.9'}, {'data': '01/05/1998', 'valor': '64.4'}, {'data': '01/06/1998', 'valor': '40.9'}, {'data': '01/07/1998', 'valor': '36.4'}, {'data': '01/08/1998', 'valor': '103.7'}, {'data': '01/09/1998', 'valor': '471.1'}, {'data': '01/10/1998', 'valor': '167.5'}, {'data': '01/11/1998', 'valor': '733.9'}, {'data': '01/12/1998', 'valor': '199.5'}, {'data': '01/01/1999', 'valor': '453.6'}, {'data': '01/02/1999', 'valor': '440.6'}, {'data': '01/03/1999', 'valor': '1038.4'}, {'data': '01/04/1999', 'valor': '830.7'}, {'data': '01/05/1999', 'valor': '55.2'}, {'data': '01/06/1999', 'valor': '220.6'}, {'data': '01/07/1999', 'valor': '116.9'}, {'data': '01/08/1999', 'valor': '138.3'}, {'data': '01/09/1999', 'valor': '47.4'}, {'data': '01/10/1999', 'valor': '25.3'}, {'data': '01/11/1999', 'valor': '20.1'}, {'data': '01/12/1999', 'valor': '4.0'}, {'data': '01/01/2000', 'valor': '14.4'}, {'data': '01/02/2000', 'valor': '17.2'}, {'data': '01/03/2000', 'valor': '2.0'}, {'data': '01/04/2000', 'valor': '54.4'}, {'data': '01/05/2000', 'valor': '67.5'}, {'data': '01/06/2000', 'valor': '27.2'}, {'data': '01/07/2000', 'valor': '15.8'}, {'data': '01/08/2000', 'valor': '261.6'}, {'data': '01/09/2000', 'valor': '24.9'}, {'data': '01/10/2000', 'valor': '75.4'}, {'data': '01/11/2000', 'valor': '52.7'}, {'data': '01/12/2000', 'valor': '18.5'}, {'data': '01/01/2001', 'valor': '11.7'}, {'data': '01/02/2001', 'valor': '50.4'}, {'data': '01/03/2001', 'valor': '37.2'}, {'data': '01/04/2001', 'valor': '3.4'}, {'data': '01/05/2001', 'valor': '122.9'}, {'data': '01/06/2001', 'valor': '198.9'}, {'data': '01/07/2001', 'valor': '25.5'}, {'data': '01/08/2001', 'valor': '79.0'}, {'data': '01/09/2001', 'valor': '53.8'}, {'data': '01/10/2001', 'valor': '195.2'}, {'data': '01/11/2001', 'valor': '151.8'}, {'data': '01/12/2001', 'valor': '132.2'}, {'data': '01/01/2002', 'valor': '19.6'}, {'data': '01/02/2002', 'valor': '100.3'}, {'data': '01/03/2002', 'valor': '17.7'}, {'data': '01/04/2002', 'valor': '125.1'}, {'data': '01/05/2002', 'valor': '49.6'}, {'data': '01/06/2002', 'valor': '6.1'}, {'data': '01/07/2002', 'valor': '130.5'}, {'data': '01/08/2002', 'valor': '15.0'}, {'data': '01/09/2002', 'valor': '22.7'}, {'data': '01/10/2002', 'valor': '33.7'}, {'data': '01/11/2002', 'valor': '102.3'}, {'data': '01/12/2002', 'valor': '36.9'}, {'data': '01/01/2003', 'valor': '69.7'}, {'data': '01/02/2003',  ...

# %%
import requests
import pandas as pd

url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.22913/dados?formato=json"

response = requests.get(url)

if response.status_code == 200:
    dados_ativos = response.json() 
    
    tabela = pd.DataFrame(dados_ativos)
    
    display(tabela)
else:
    print("Erro ao conseguir os dados!. Status Code:", response.status_code)
# Out:
#            data   valor
# 0    01/01/1995     0.6
# 1    01/02/1995    11.7
# 2    01/03/1995    15.0
# 3    01/04/1995     5.3
# 4    01/05/1995    20.2
# ..          ...     ...
# 345  01/10/2023  3586.4
# 346  01/11/2023  2264.3
# 347  01/12/2023  3990.4
# 348  01/01/2024  2863.9
# 349  01/02/2024  2967.9
#
# [350 rows x 2 columns]
