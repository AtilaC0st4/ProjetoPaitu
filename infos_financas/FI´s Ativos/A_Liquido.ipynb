# %%
# ! pip install request

# %%
import requests
import json

url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.22912/dados?formato=json"

response = requests.get(url)

if response.status_code == 200:
    dados_ativos = response.json() 
    
    print("Dados coletados:")
    print(dados_ativos)
else:
    print("Erro ao conseguir os dados!. Status Code:", response.status_code)
# Out:
# Dados coletados:
# [{'data': '01/01/1995', 'valor': '19.4'}, {'data': '01/02/1995', 'valor': '53.8'}, {'data': '01/03/1995', 'valor': '71.4'}, {'data': '01/04/1995', 'valor': '-0.5'}, {'data': '01/05/1995', 'valor': '-15.5'}, {'data': '01/06/1995', 'valor': '6.8'}, {'data': '01/07/1995', 'valor': '4.2'}, {'data': '01/08/1995', 'valor': '-3.3'}, {'data': '01/09/1995', 'valor': '24.2'}, {'data': '01/10/1995', 'valor': '23.9'}, {'data': '01/11/1995', 'valor': '-11.2'}, {'data': '01/12/1995', 'valor': '-4.9'}, {'data': '01/01/1996', 'valor': '1.2'}, {'data': '01/02/1996', 'valor': '3.2'}, {'data': '01/03/1996', 'valor': '15.8'}, {'data': '01/04/1996', 'valor': '27.5'}, {'data': '01/05/1996', 'valor': '1.4'}, {'data': '01/06/1996', 'valor': '5.3'}, {'data': '01/07/1996', 'valor': '-1.1'}, {'data': '01/08/1996', 'valor': '52.9'}, {'data': '01/09/1996', 'valor': '-81.7'}, {'data': '01/10/1996', 'valor': '11.3'}, {'data': '01/11/1996', 'valor': '-4.9'}, {'data': '01/12/1996', 'valor': '0.6'}, {'data': '01/01/1997', 'valor': '4.8'}, {'data': '01/02/1997', 'valor': '0.5'}, {'data': '01/03/1997', 'valor': '3.9'}, {'data': '01/04/1997', 'valor': '-13.9'}, {'data': '01/05/1997', 'valor': '-3.2'}, {'data': '01/06/1997', 'valor': '7.8'}, {'data': '01/07/1997', 'valor': '-3.6'}, {'data': '01/08/1997', 'valor': '1.7'}, {'data': '01/09/1997', 'valor': '31.3'}, {'data': '01/10/1997', 'valor': '68.7'}, {'data': '01/11/1997', 'valor': '113.7'}, {'data': '01/12/1997', 'valor': '-71.6'}, {'data': '01/01/1998', 'valor': '-4.4'}, {'data': '01/02/1998', 'valor': '-17.2'}, {'data': '01/03/1998', 'valor': '-31.8'}, {'data': '01/04/1998', 'valor': '7.5'}, {'data': '01/05/1998', 'valor': '-32.7'}, {'data': '01/06/1998', 'valor': '-1.0'}, {'data': '01/07/1998', 'valor': '1.8'}, {'data': '01/08/1998', 'valor': '489.3'}, {'data': '01/09/1998', 'valor': '842.2'}, {'data': '01/10/1998', 'valor': '47.4'}, {'data': '01/11/1998', 'valor': '-713.8'}, {'data': '01/12/1998', 'valor': '-81.4'}, {'data': '01/01/1999', 'valor': '1131.8'}, {'data': '01/02/1999', 'valor': '-95.0'}, {'data': '01/03/1999', 'valor': '-649.8'}, {'data': '01/04/1999', 'valor': '-813.5'}, {'data': '01/05/1999', 'valor': '-34.8'}, {'data': '01/06/1999', 'valor': '-119.2'}, {'data': '01/07/1999', 'valor': '-115.2'}, {'data': '01/08/1999', 'valor': '-14.0'}, {'data': '01/09/1999', 'valor': '-41.6'}, {'data': '01/10/1999', 'valor': '-15.4'}, {'data': '01/11/1999', 'valor': '-15.5'}, {'data': '01/12/1999', 'valor': '14.3'}, {'data': '01/01/2000', 'valor': '41.5'}, {'data': '01/02/2000', 'valor': '21.3'}, {'data': '01/03/2000', 'valor': '23.0'}, {'data': '01/04/2000', 'valor': '-21.1'}, {'data': '01/05/2000', 'valor': '-57.1'}, {'data': '01/06/2000', 'valor': '33.5'}, {'data': '01/07/2000', 'valor': '25.2'}, {'data': '01/08/2000', 'valor': '25.9'}, {'data': '01/09/2000', 'valor': '17.8'}, {'data': '01/10/2000', 'valor': '-37.8'}, {'data': '01/11/2000', 'valor': '-33.8'}, {'data': '01/12/2000', 'valor': '-10.7'}, {'data': '01/01/2001', 'valor': '51.3'}, {'data': '01/02/2001', 'valor': '-6.0'}, {'data': '01/03/2001', 'valor': '-28.6'}, {'data': '01/04/2001', 'valor': '127.5'}, {'data': '01/05/2001', 'valor': '1.0'}, {'data': '01/06/2001', 'valor': '-106.6'}, {'data': '01/07/2001', 'valor': '185.2'}, {'data': '01/08/2001', 'valor': '12.3'}, {'data': '01/09/2001', 'valor': '-0.6'}, {'data': '01/10/2001', 'valor': '-37.4'}, {'data': '01/11/2001', 'valor': '-99.1'}, {'data': '01/12/2001', 'valor': '-39.8'}, {'data': '01/01/2002', 'valor': '-1.2'}, {'data': '01/02/2002', 'valor': '-13.6'}, {'data': '01/03/2002', 'valor': '44.3'}, {'data': '01/04/2002', 'valor': '-65.7'}, {'data': '01/05/2002', 'valor': '47.7'}, {'data': '01/06/2002', 'valor': '71.7'}, {'data': '01/07/2002', 'valor': '-122.2'}, {'data': '01/08/2002', 'valor': '71.7'}, {'data': '01/09/2002', 'valor': '12.4'}, {'data': '01/10/2002', 'valor': '7.1'}, {'data': '01/11/2002', 'valor': '-75.5'}, {'data': '01/12/2002', 'valor': '-8.8'}, {'data': '01/01/2003', 'valor': ...

# %%
import requests
import pandas as pd

url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.22912/dados?formato=json"

response = requests.get(url)

if response.status_code == 200:
    dados_ativos = response.json() 
    
    tabela = pd.DataFrame(dados_ativos)
    
    display(tabela)
else:
    print("Erro ao conseguir os dados!. Status Code:", response.status_code)
# Out:
#            data    valor
# 0    01/01/1995     19.4
# 1    01/02/1995     53.8
# 2    01/03/1995     71.4
# 3    01/04/1995     -0.5
# 4    01/05/1995    -15.5
# ..          ...      ...
# 345  01/10/2023   -294.8
# 346  01/11/2023     84.7
# 347  01/12/2023  -1606.4
# 348  01/01/2024   -696.1
# 349  01/02/2024   1359.5
#
# [350 rows x 2 columns]
